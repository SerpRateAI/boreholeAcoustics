# %%
# %matplotlib inline
import obspy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates


from hydrophone_data_processing import load, preprocessing, tempmatch
# from multitaper.multitaper import Multitaper
# from spectrum import *
import spectrum

# %%
detectfiles = '/media/sda/data/borehole/detections/*.csv'
bubbles = load.import_detections(detectfiles)

# %%
bubbles#[bubbles.time.between('2019-05-01', '2019-05-03')]
# Out:
#                                time  similarity  template_id
# 0  2019-05-02 08:34:05.219999+00:00    0.879116            0
# 1  2019-05-02 08:34:56.173999+00:00    0.850827            0
# 2  2019-05-02 10:27:54.056999+00:00    0.860519            0
# 3  2019-05-02 12:08:43.894999+00:00    0.906010            0
# 4  2019-05-02 12:09:15.602999+00:00    0.814478            0
# ..                              ...         ...          ...
# 0  2020-02-02 00:49:47.295000+00:00    0.827654            0
# 1  2020-02-02 05:41:40.738000+00:00    0.814375            0
# 2  2020-02-02 12:32:29.838000+00:00    0.818918            0
# 3  2020-02-02 22:43:12.641000+00:00    0.817783            0
# 0  2020-02-03 09:30:09.057000+00:00    0.801085            0
#
# [2499 rows x 3 columns]

# %%
paths = ['/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.01.GDH.2019.122'
        ,'/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.02.GDH.2019.122'
        ,'/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.03.GDH.2019.122'
        ,'/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.04.GDH.2019.122'
        ,'/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.05.GDH.2019.122'
        ,'/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.06.GDH.2019.122']

day122 = load.import_corrected_data_for_single_day(paths=paths)

# %%
s = obspy.UTCDateTime(bubbles.time.iloc[3])
e = s+1
day122.plot(starttime=s, endtime=e)
