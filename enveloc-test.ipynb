# %%
# !pip install enveloc
# Out:
# ...
#   Using cached proj-0.2.0-py2.py3-none-any.whl (8.6 kB)
# ...
#      |████████████████████████████████| 97 kB 4.5 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s  eta 0:00:01
# ...
#   Created wheel for enveloc: filename=enveloc-1.1.3-py3-none-any.whl size=28067 sha256=b5d6fdeecc1a0b66ce2f69a7210d25031f8d0defb3eb9ef7671f7ac8724ead46
#   Stored in directory: /home/john/.cache/pip/wheels/49/9c/17/6bd9859dc5cac46e19c72fa64f3416422f18dedaab1c03227d
# Successfully built enveloc
# ...

# %%
from enveloc.example_utils import test
test()
# Out:
# ...
#
# Adding lat/lon info...
#
# HV.BYL..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# HV.DEVL..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# HV.HAT..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# HV.KKO..HHZ | 2018-04-28T13:06:50.000000Z - 2018-04-28T13:09:10.000000Z | 100.0 Hz, 14001 samples
# HV.NPT..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# HV.OBL..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# HV.PAUD..HHZ | 2018-04-28T13:06:50.000000Z - 2018-04-28T13:09:10.000000Z | 100.0 Hz, 14001 samples
# HV.PUHI..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# HV.RIMD..HHZ | 2018-04-28T13:06:50.005000Z - 2018-04-28T13:09:09.995000Z | 100.0 Hz, 14000 samples
# ...
