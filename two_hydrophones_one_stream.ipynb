# %%
# %matplotlib inline
from obspy import read, UTCDateTime as UTC
from obspy.signal.cross_correlation import correlation_detector
import obspy
import io
import matplotlib.pyplot as plt
import helpers
import numpy as np
import pandas as pd

from obspy.signal import trigger
from obspy.signal import filter

from datetime import datetime

from multiprocessing import Pool
import glob

import tempmatch as tm

# %%
data = tm.digest_data('/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.01.GDH.2019.138')
data += tm.digest_data('/media/sda/data/robdata/Hydrophones/DAYS/B00/B00.7F.02.GDH.2019.138')

# %%
templates = data.select(id='7F.B00.01.GDH').slice(UTC('2019-05-18T14:36:16.178Z'), UTC('2019-05-18T14:36:16.304Z'))
templates += data.select(id='7F.B00.02.GDH').slice(UTC('2019-05-18T14:36:16.22Z'), UTC('2019-05-18T14:36:16.35Z'))

# %%
_ = templates.plot()

# %%
templates.spectrogram(cmap='nipy_spectral')
# Out:
# [None, None]

# %%
height = 0.8
distance = 1.1

detections, sims = correlation_detector(stream=data
                                       ,templates=templates
                                       ,heights=height
                                       ,distance=distance
                                       ,plot=data
                                       ,details=True)

# %%
plt.hist(sims[0].data, bins=np.linspace(-1, 1, 201))
plt.yscale('log')

# %%
df = pd.DataFrame(detections)
df['time'] = pd.to_datetime(df['time'].astype(str))
df.sort_values(by='time', inplace=True)
df['ones'] = 1
df.set_index('time', inplace=True)
df['cc_b00.01'] = df.cc_values.apply(lambda x: x['7F.B00.01.GDH'])
df['cc_b00.02'] = df.cc_values.apply(lambda x: x['7F.B00.02.GDH'])

# %%
df.head()
# Out:
#                                   similarity  \
# time
# 2019-05-18 11:45:45.948000+00:00    0.961165
# 2019-05-18 11:47:16.325000+00:00    0.967291
# 2019-05-18 11:47:54.450000+00:00    0.963086
# 2019-05-18 11:49:19.032000+00:00    0.980351
# 2019-05-18 11:49:27.501000+00:00    0.971060
#
#                                                                           cc_values  \
# time
# 2019-05-18 11:45:45.948000+00:00  {'7F.B00.01.GDH': 0.961882852154, '7F.B00.02.G...
# 2019-05-18 11:47:16.325000+00:00  {'7F.B00.01.GDH': 0.968174971844, '7F.B00.02.G...
# 2019-05-18 11:47:54.450000+00:00  {'7F.B00.01.GDH': 0.957940504348, '7F.B00.02.G...
# 2019-05-18 11:49:19.032000+00:00  {'7F.B00.01.GDH': 0.978991776853, '7F.B00.02.G...
# 2019-05-18 11:49:27.501000+00:00  {'7F.B00.01.GDH': 0.972505688606, '7F.B00.02.G...
#
#                                   template_id  ones  cc_b00.01  cc_b00.02
# time
# 2019-05-18 11:45:45.948000+00:00            0     1   0.961883   0.960447
# 2019-05-18 11:47:16.325000+00:00            0     1   0.968175   0.966407
# 2019-05-18 11:47:54.450000+00:00            0     1   0.957941   0.968231
# 2019-05-18 11:49:19.032000+00:00            0     1   0.978992   0.981711
# 2019-05-18 11:49:27.501000+00:00            0     1   0.972506   0.969615

# %%
df['cc_b00.01'].plot(figsize=(20,5))
df['cc_b00.02'].plot(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.cc_values[0]
# Out:
# {'7F.B00.01.GDH': 0.96188285215390723, '7F.B00.02.GDH': 0.96044652284227017}

# %%
df.describe()
# Out:
#        similarity  template_id   ones
# count  406.000000        406.0  406.0
# mean     0.957253          0.0    1.0
# std      0.039027          0.0    0.0
# min      0.802439          0.0    1.0
# 25%      0.950489          0.0    1.0
# 50%      0.969234          0.0    1.0
# 75%      0.982162          0.0    1.0
# max      1.000000          0.0    1.0

# %%
fig, ax = plt.subplots(figsize=(10, 5))
df.cumsum()['ones'].plot(ax=ax, color='dodgerblue')

ax2 = ax.twinx()
df.similarity.rolling(window=5).mean().plot(ax=ax2, color='darkorange', alpha=0.5)
ax2.set_ylabel('CC-score, rolling mean window=20 events')
# ax.set_yscale('log')
ax.set_ylabel('cumulative number of events')
# ax.set_yscale('log')
# Out:
# Text(0, 0.5, 'cumulative number of events')
