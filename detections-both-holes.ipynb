# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import obspy
from hydrophone_data_processing import load

# %%
df = load.import_detections('/media/sda/data/borehole/detections/*.csv')

# %%
df.reset_index()
# Out:
#     index                         time  similarity  template_id
# 0       0  2019-05-23T09:50:08.937000Z    0.878120            0
# 1       0  2019-05-27T14:01:42.332000Z    0.896187            0
# 2       0  2019-06-05T19:22:09.245999Z    0.845635            0
# 3       0  2019-05-25T14:52:00.309000Z    0.832567            0
# 4       0  2019-06-03T09:33:05.746000Z    0.803248            0
# 5       0  2019-05-06T01:07:42.741000Z    0.804644            0
# 6       1  2019-05-06T01:12:03.352000Z    0.806152            0
# 7       2  2019-05-06T01:13:41.044000Z    0.871673            0
# 8       3  2019-05-06T01:14:03.443000Z    0.822991            0
# 9       4  2019-05-06T08:00:38.684000Z    0.844727            0
# 10      5  2019-05-06T08:01:44.606000Z    0.890552            0
# 11      6  2019-05-06T22:39:35.278000Z    0.878664            0
# 12      0  2019-05-30T03:05:21.896000Z    0.823386            0
# 13      0  2019-05-05T07:05:49.813000Z    0.853986            0
# ...

# %%
# import glob

# %%
# glob.glob('/media/sda/data/borehole/detections/*.csv')
